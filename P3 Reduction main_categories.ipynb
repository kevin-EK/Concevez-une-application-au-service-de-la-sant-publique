# %% [markdown]
# # P3 Concevez une application au service de la santé publique

# %% [markdown]
# L'agence <span style='color:blue'> <a href = "http://www.santepubliquefrance.fr/">"*Santé publique France*" </a></span> a lancé un appel à projets pour trouver des idées innovantes d’applications en lien avec l'alimentation. <br>
# Vous souhaitez y participer et proposer une idée d’application.

# %% [markdown]
# Le jeu de données <font color='orange'>Open Food Facts</font> est disponible sur le <a href = "https://world.openfoodfacts.org/">site officiel</a> (ou disponible à <a href ="https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/parcours-data-scientist/P2/fr.openfoodfacts.org.products.csv.zip">ce lien</a> en téléchargement).
# <br>
# Les variables sont définies à <a href = "https://world.openfoodfacts.org/data/data-fields.txt">cette adresse</a>

# %% [markdown]
# Les champs sont séparés en quatre sections :
#
# - Les informations générales sur la fiche du produit : nom, date de modification, etc.
# - Un ensemble de tags : catégorie du produit, localisation, origine, etc.
# - Les ingrédients composant les produits et leurs additifs éventuels.
# - Des informations nutritionnelles : quantité en grammes d’un nutriment pour 100 grammes du produit.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
import os

import missingno as msno

# %%
categories = pd.read_csv("fr.openfoodfacts.org.products.csv",
                         sep='\t',
                         usecols = ["main_category","main_category_fr","categories","categories","categories_fr","categories_tags"])

# %%
categories.head()
# Out:
#   categories categories_tags categories_fr main_category main_category_fr
# 0        NaN             NaN           NaN           NaN              NaN
# 1        NaN             NaN           NaN           NaN              NaN
# 2        NaN             NaN           NaN           NaN              NaN
# 3        NaN             NaN           NaN           NaN              NaN
# 4        NaN             NaN           NaN           NaN              NaN

# %% [raw]
# Suppression des lignes qui sont entierrement nulles

# %%
categories = categories.dropna(how='all')

# %% [markdown]
# Nombre de ligne et de colonnes

# %%
nrows,ncols = categories.shape

# %%
nrows,ncols
# Out:
# (84412, 5)

# %% [raw]
# Description de notre base de données

# %%
categories.describe()
# Out:
#                                         categories  \
# count                                        84410
# unique                                       36982
# top     Snacks sucrés,Biscuits et gâteaux,Biscuits
# freq                                           301
#
#                                           categories_tags  \
# count                                               84389
# unique                                              21142
# top     en:sugary-snacks,en:biscuits-and-cakes,en:bisc...
# freq                                                  802
#
#                                      categories_fr main_category  \
# count                                        84411         84366
# unique                                       21152          3543
# top     Snacks sucrés,Biscuits et gâteaux,Biscuits  en:beverages
# freq                                           802          6054
#
#        main_category_fr
# count             84366
# unique             3543
# top            Boissons
# freq               6054

# %% [raw]
# Ci-dessous la distribution des modalités de main_category_fr non traduites.
# Ces moadlités seront ensuites exportées puis traduites grace à deepl

# %%
categories.main_category_fr.str.replace('(?<=\\:).+','',regex=True).value_counts().head(20)
# Out:
# Boissons                                   6054
# Epicerie                                   2902
# Chocolats                                  2789
# Aliments et boissons à base de végétaux    2745
# Conserves                                  2519
# Biscuits                                   2097
# Plats préparés                             2079
# Snacks sucrés                              1946
# Surgelés                                   1889
# Petit-déjeuners                            1793
# Fromages                                   1785
# Pains                                      1771
# en:                                        1686
# Desserts                                   1684
# Pâtes alimentaires                         1529
# Plats à base de viande                     1319
# Gâteaux                                    1266
# Chips et frites                            1222
# Produits à tartiner salés                  1181
# Bonbons                                    1113
# Name: main_category_fr, dtype: int64

# %% [raw]
# pd.DataFrame({'main_cate':categories['main_category_fr'][categories['main_category_fr'].str.contains('^en:').fillna(False).to_list()].to_list()})\
# .to_excel('main_cateen.xlsx')
#
# pd.DataFrame({'main_cate':categories['main_category_fr'][categories['main_category_fr'].str.contains('^it:').fillna(False).to_list()].to_list()})\
# .to_excel('main_cateit.xlsx')
#
# pd.DataFrame({'main_cate':categories['main_category_fr'][categories['main_category_fr'].str.contains('^de:').fillna(False).to_list()].to_list()})\
# .to_excel('main_catede.xlsx')
#
# pd.DataFrame({'main_cate':categories['main_category_fr'][categories['main_category_fr'].str.contains('^es:').fillna(False).to_list()].to_list()})\
# .to_excel('main_catees.xlsx')
#
# pd.DataFrame({'main_cate':categories['main_category_fr'][categories['main_category_fr'].str.contains('^pt:').fillna(False).to_list()].to_list()})\
# .to_excel('main_catept.xlsx')
#
# pd.DataFrame({'main_cate':categories['main_category_fr'][categories['main_category_fr'].str.contains('^pl:').fillna(False).to_list()].to_list()})\
# .to_excel('main_catepl.xlsx')

# %% [raw]
# corr_main_categories = pd.read_excel('main_cate.xlsx')
# corr_main_categories = corr_main_categories[corr_main_categories.traduit>0][["main_cate","translate english"]]

# %% [raw]
# categories = categories.merge(right=corr_main_categories,
#                  how='left',
#                  left_on='main_category_fr_en',
#                  right_on='main_cate')[['main_category','main_category_fr','main_category_fr_en','translate english']]\
# .drop_duplicates()

# %% [raw]
# Import du fichiers contenant les differents traductions et merge avec le dataframe initial

# %%
corr_main_categories_esdeptitpl = pd.read_excel('main_cateptplitesdeen.xlsx')
#corr_main_categories_esdeptitpl = corr_main_categories_esdeptitpl[corr_main_categories_esdeptitpl.traduit>0][["main_cate","translate english"]]

# %%
corr_main_categories_esdeptitpl.head()
# Out:
#                  main_cate        langue origine  \
# 0  pt:Salgadinho-de-batata  Salgadinho de batata
# 1               pt:Cereais               Cereais
# 2                pt:Molhos                Molhos
# 3             pt:Refeicoes             Refeicoes
# 4              pt:Salgados              Salgados
#
#                             traduit
# 0  En-cas à base de pommes de terre
# 1                          Céréales
# 2                            Sauces
# 3                             Repas
# 4                            Snacks

# %% [raw]
# categories[categories.main_category_fr=='de:Trockenfeigen'].merge(right=corr_main_categories_esdeptitpl[corr_main_categories_esdeptitpl.main_cate=='de:Trockenfeigen'],
#                  how='left',
#                  left_on='main_category_fr',
#                  right_on='main_cate')[['main_category','main_category_fr','main_category_fr_en','translate english','traduit']]\
# .drop_duplicates()

# %%
categories = categories.merge(right=corr_main_categories_esdeptitpl,
                 how='left',
                 left_on='main_category_fr',
                 right_on='main_cate')[['main_category','main_category_fr','traduit']]\
.drop_duplicates()

# %% [markdown]
# </br>

# %%
categories.describe()
# Out:
#             main_category main_category_fr            traduit
# count                3543             3543               1860
# unique               3543             3543               1660
# top     fr:filet-de-boeuf   Filet-de-boeuf  Produits laitiers
# freq                    1                1                  9

# %%
### Correction lower - et ^[a-Z]:

# %%
categories.main_category_fr.str.lower().str.replace('-',' ',regex=True).str.replace('^[a-z]{2}\\:','',regex=True).sample(10)
# Out:
# 30733          sauce pour risotto
# 3536                  indian food
# 42828                    asperges
# 946             grape juice drink
# 78969                      dulces
# 3914             lingonberry jams
# 41114    decorations alimentaires
# 1614              hot dog mustard
# 80584               tuiles salees
# 75521          gelatina per dolci
# Name: main_category_fr, dtype: object

# %%
categories.traduit.sample(10)
# Out:
# 10062                           Miel australien pur
# 30121                                           NaN
# 3519                                            NaN
# 71954                          Lait UHT homogénéisé
# 8143                          Epis de maïs congelés
# 46771                                           NaN
# 1140                                 Moutarde jaune
# 81584    Pâte à tartiner à base de graisse végétale
# 2328                              Sirop pour crêpes
# 42971                                           NaN
# Name: traduit, dtype: object

# %%
categories['traduit'].str.lower()\
.str.replace('[éèëê]','e',regex=True)\
.str.replace('[àäâ]','a',regex=True)\
.str.replace('[ïîì]','i',regex=True)\
.str.replace('[ôöù]','o',regex=True)\
.str.replace('[ûüù]','u',regex=True)\
.str.replace('[œ]','oe',regex=True)\
.str.replace('[a-z ]','',regex=True).value_counts()
# Out:
#                                      1743
# '                                      78
# -                                      22
# ''                                      4
# пряники                                 1
# ı                                       1
# -'                                      1
# шоколадссолёнымминдалёмикарамелью       1
# ç                                       1
# светлоепиво                             1
# биойогурты                              1
# кетчуп                                  1
# うまい棒                                    1
# 12                                      1
# 1                                       1
# 15                                      1
# 'ç                                      1
# Name: traduit, dtype: int64

# %% [raw]
# pd.options.display.max_rows=60
# categories['main_category_fr'].str.lower()\
# .str.replace('[éèëê]','e',regex=True)\
# .str.replace('[àäâ]','a',regex=True)\
# .str.replace('[ïîì]','i',regex=True)\
# .str.replace('[ôöù]','o',regex=True)\
# .str.replace('[ûüù]','u',regex=True)\
# .str.replace('[œ]','oe',regex=True)\
# .str.replace('[a-z ]','',regex=True).value_counts().head(60)

# %% [raw]
# Creation de la colonne 'main_category_fr_cor':
#     - lower()
#     - remplacement des '-' par ' '
#     - suppression des indicateurs de language ^[a-z]{2}:
#     - suppression des accents

# %%
categories['main_category_fr_cor'] = [ y if y is not np.nan else x for x,y in zip(categories.main_category_fr,categories.traduit)]


categories['main_category_fr_cor'] = categories['main_category_fr_cor'].str.lower()\
.str.replace('-',' ',regex=True)\
.str.replace('[éèëê]','e',regex=True)\
.str.replace('[àäâ]','a',regex=True)\
.str.replace('[ïîì]','i',regex=True)\
.str.replace('[ôöù]','o',regex=True)\
.str.replace('[ûüù]','u',regex=True)\
.str.replace('^[a-z]{2}\\:','',regex=True)\
.str.replace('œ','oe',regex=True)

# %%
categories.describe()
# Out:
#             main_category main_category_fr            traduit  \
# count                3543             3543               1860
# unique               3543             3543               1660
# top     fr:filet-de-boeuf   Filet-de-boeuf  Produits laitiers
# freq                    1                1                  9
#
#        main_category_fr_cor
# count                  3543
# unique                 3164
# top       produits laitiers
# freq                     10

# %% [raw]
# On a réduit le nombre de modalités de main_categories. On passe de 3543 à 3164 modalités

# %%
categories.loc[(categories.main_category_fr_cor.str.contains('s$').fillna(False)) & ~(categories.main_category_fr_cor.str.contains('frais$').fillna(False))].sample(5)
# Out:
#                  main_category            main_category_fr          traduit  \
# 83576         en:frozen-donuts            en:Frozen-donuts  Beignets glacés
# 22563  fr:coulis-de-framboises        Coulis-de-framboises              NaN
# 2                  en:pastries                 Pâtisseries              NaN
# 37          en:chips-and-fries             Chips et frites              NaN
# 974           en:sweet-spreads  Produits à tartiner sucrés              NaN
#
#              main_category_fr_cor
# 83576             beignets glaces
# 22563        coulis de framboises
# 2                     patisseries
# 37                chips et frites
# 974    produits a tartiner sucres

# %% [raw]
# Creation de la colonne main_category_fr_cor_2
# On veut rassembler les modalités identiques pluriel et singulier ensembles [distance de levenshtein <=2 ]

# %%
from Levenshtein import distance as levenshtein_distance
dico_proche = []

categories['main_category_fr_cor_2']=''

for ks in categories.loc[(categories.main_category_fr_cor.str.contains('s$').fillna(False)) & ~(categories.main_category_fr_cor.str.contains('frais$').fillna(False)),'main_category_fr_cor'].unique():
    ks_list = []
    
    for k in categories.main_category_fr_cor.unique():
        if ks is not np.nan and k  is not np.nan and ks != k and len(ks) > 4 and levenshtein_distance(ks,k) <= 2 and k[-1] != 's' and len(ks.split(' ')) >1:
            # les mots composés
            
            # add item in list
            dico_proche.append([ks,k])
            
        if ks is not np.nan and k  is not np.nan and ks != k and len(ks) > 4 and levenshtein_distance(ks,k) <= 1 and k[-1] != 's' and len(ks.split(' '))==1:
            # les mots simples
            
            # add item in list
            dico_proche.append([ks,k])
            
        #if k not in ['macaroni','păine','paine','toats','bigos','bison','alinos','aligot']:
            #categories.loc[categories.main_category_fr_cor == k,['main_category_fr_cor_2']] = ks

# %% [markdown]
# </br>

# %%
for ks in categories.loc[(categories.main_category_fr_cor.str.contains('s$').fillna(False)) & ~(categories.main_category_fr_cor.str.contains('frais$').fillna(False)),'main_category_fr_cor'].unique():
    for k in categories.main_category_fr_cor.unique():
        if ks is not np.nan and k  is not np.nan and ks != k and len(ks) > 4 and levenshtein_distance(ks,k) <= 2 and k[-1] != 's' and len(ks.split(' ')) >1:
            # les mots composés
            
            # add item in list
            dico_proche.append([ks,k])
            
        if ks is not np.nan and k  is not np.nan and ks != k and len(ks) > 4 and levenshtein_distance(ks,k) <= 1 and k[-1] != 's' and len(ks.split(' '))==1:
            # les mots simples
            
            # add item in list
            dico_proche.append([ks,k])
            
        #if k not in ['macaroni','păine','paine','toats','bigos','bison','alinos','aligot']:
            #categories.loc[categories.main_category_fr_cor == k,['main_category_fr_cor_2']] = ks

# %%
for ll in dico_proche:
    if k not in ['macaroni','păine','paine','toats','bigos','bison','alinos','aligot']:
        categories.loc[categories.main_category_fr_cor == ll[1],['main_category_fr_cor_2']] = ll[0]

# %%
categories[categories.main_category_fr_cor_2!=""].sample(10)
# Out:
#               main_category      main_category_fr               traduit  \
# 5140          fr:bruschetta            Bruschetta                   NaN
# 10390             de:muffin             de:Muffin                Muffin
# 57677              en:sirop              en:Sirop                 Sirop
# 1261    en:prepared-chicken   en:Prepared-chicken        Poulet préparé
# 65160    en:food-coulouring    en:Food-coulouring  Colorant alimentaire
# 50738    fr:puree-de-piment       Puree-de-piment                   NaN
# 10586            es:pescado            es:Pescado               Poisson
# 74697  pt:biscoito-integral  pt:Biscoito-integral       Biscuit complet
# 65301              en:yeast              en:Yeast                Levure
# 65918               en:pate               en:Pate                  Pate
#
#        main_category_fr_cor  main_category_fr_cor_2
# 5140             bruschetta             bruschettas
# 10390                muffin                 muffins
# 57677                 sirop                  sirops
# 1261         poulet prepare        poulets prepares
# 65160  colorant alimentaire  colorants alimentaires
# 50738       puree de piment        puree de piments
# 10586               poisson                poissons
# 74697       biscuit complet       biscuits complets
# 65301                levure                 levures
# 65918                  pate                   pates

# %% [markdown]
# </br>

# %%
for ks in categories.loc[(categories.main_category_fr_cor.str.contains('s$').fillna(False)) & ~(categories.main_category_fr_cor.str.contains('frais$').fillna(False)),'main_category_fr_cor'].unique():
    for k in categories.main_category_fr_cor.unique():
        
        if ks is not np.nan and k is not np.nan and ks != k and len(ks) > 4 and levenshtein_distance(ks,k) <= 2 and k[-1] != 's':

            # add item in list
            print(str(ks).ljust(25)+' | '+str(k).ljust(15) )
            
            if k not in ['macaroni','tomate','apero','macaroni','păine','mate','boeuf','paine','toats','bigos','pains de mie','bison','boisson','alinos','aligot']:
                categories.loc[categories.main_category_fr_cor == k,['main_category_fr_cor_2']] = ks
# Out:
# patisseries               | pattisserie
# patisseries               | patisserie
# pains                     | paine
# pains                     | păine
# volailles                 | volaille
# sirops                    | sirop
# sirops                    | siroop
# viandes                   | viande
# soupes                    | soupe
# charcuteries              | charcuterie
# chocolats                 | chocolat
# chocolats                 | chocolade
# chocolats                 | ciocolată
# boissons                  | poisson
# boissons                  | boisson
# sandwichs                 | sandwitch
# farines                   | farine
# farines                   | farina
# conserves                 | conserve
# yaourts                   | yaourt
# huiles                    | huile
# biscuits                  | biscuiți
# biscuits                  | biscoito
# biscuits                  | biscuit
# biscuits                  | bbiscuit
# tomates                   | tomate
# sucres                    | sucre
# jus de fruits             | jus de fruit
# edulcorants               | edulcorant
# vinaigres                 | vinaigre
# fromages                  | fromage
# laits                     | lait
# laits                     | lapte
# beurres                   | beurre
# glaces                    | glace
# boissons gazeuses         | boisson gazeuse
# cremes                    | creme
# thes verts                | the vert
# tartinades de fruits      | tartinade de fruit
# poissons                  | poisson
# poissons                  | boisson
# muffins                   | muffin
# nectars de fruits         | nectar de fruit
# salades                   | salade
# thons                     | thon
# fromages blancs           | fromage blanc
# snacks                    | snack
# pains de mais             | pains de mie
# jambons crus              | jambon cru
# pates                     | pate
# pates                     | mate
# thes glaces               | the glace
# tortillas                 | tortilla
# sauces                    | sauce
# biscottes                 | biscotti
# feculents                 | feculent
# confits d oignons         | confits d oignon
# pancakes                  | pancake
# oeufs                     | boeuf
# pralines                  | pralinen
# levures                   | levure
# potages                   | potage
# preparations pour pains   | preparation pour pain
# jambons fumes             | jambon fume
# vermicelles               | vermicelle
# oeufs de poissons         | oeufs de poisson
# aides culinaires          | aide culinaire
# confit d oignons          | confits d oignon
# macarons                  | macaroni
# donuts                    | donut
# amers                     | apero
# preparations culinaires   | preparation culinaire
# bieres                    | bier
# bieres                    | biere
# levures chimiques         | levure chimique
# haricots beurres          | haricots beurre
# confits                   | confit
# preparations pour desserts | preparations pour dessert
# fecules                   | feculent
# meringues                 | meringue
# toats                     | tomate
# faisselles                | faisselle
# cremes brulees            | creme brulee
# caviars d aubergines      | caviars d aubergine
# piperades                 | piperade
# gnocchis                  | gnocchi
# poulets prepares          | poulet prepare
# coulis de framboises      | coulis de framboise
# farces                    | farce
# garnitures                | garniture
# cafes solubles            | cafe soluble
# salades de fruits         | salade de fruit
# salades de pates          | salade de pate
# cakes sales               | cake sale
# cremes desserts           | creme dessert
# succes                    | sucre
# cancoillottes             | cancoillotte
# salade de pates           | salade de pate
# caviars d aubegines       | caviars d aubergine
# pates de volailles        | pates de volaille
# pates de volailles        | pate de volaille
# levains                   | levain
# genoises                  | genoise
# pates de foies            | pates de foie
# purees de piments         | puree de piment
# preparations pour flans   | preparation pour flan
# salade de fruits          | salade de fruit
# gommes                    | gomme
# steaks vegetales pour hamburgers | steaks vegetales pour hamburger
# gateaux secs              | gateaux sec
# puree de piments          | puree de piment
# aligots                   | aligot
# crumbles                  | crumble
# coulis de fraises         | coulis de fraise
# bruschettas               | bruschetta
# oeufs de poules           | oeufs de poule
# gels energetiques         | gel energetique
# sushis                    | sushki
# sushis                    | sushi
# melange salades           | melange salade
# nectar de fruits          | nectar de fruit
# preparations pour boissons | preparation pour boisson
# colorants alimentaires    | colorant alimentaire
# petits pains              | petit pain
# eaux minerales            | eau minerale
# cocktail de crevettes     | cocktail de crevette
# vins rouges               | vin rouge
# chocolats noirs           | chocolat noir
# calmars                   | calamar
# bigos                     | bison
# magarines                 | margarine
# beignets de crevettes     | beignets de crevette
# alinos                    | aligot
# bieres blondes            | biere blonde
# soupes deshydratees       | soupe deshydratee
# laits maternises          | lait maternise
# poisons                   | poisson
# chocolats chauds          | chocolat chaud
# boissons non alcoolisees  | boisson non alcoolisee
# amuse gueules             | amuse gueule
# graines                   | grain
# biscuits aperitifs        | biscuits aperitif
# vinaigres balsamiques     | vinaigre balsamique
# purees de fruits          | puree de fruit
# biscuits complets         | biscuit complet
# viandes sechees           | viande sechee
# marinades                 | marinade
# root beers                | root bier
# root beers                | root beer

# %%
categories[categories.main_category_fr_cor_2!=""].sample(10)
# Out:
#                      main_category          main_category_fr     traduit  \
# 60275                     en:biere                  en:Biere       Biere
# 81169  fr:preparation-pour-boisson  Preparation-pour-boisson         NaN
# 8204                       pt:grao                   pt:Grao       Grain
# 9985                      en:gravy                  en:Gravy       Sauce
# 83386                  de:backware               de:Backware  Pâtisserie
# 73399                      en:lait                   en:Lait        Lait
# 1640                 en:bruschetta             en:Bruschetta  Bruschetta
# 76250                  en:biscotti               en:Biscotti    Biscotti
# 38732                    fr:levain                    Levain         NaN
# 76612                    en:farina                 en:Farina      Farina
#
#            main_category_fr_cor      main_category_fr_cor_2
# 60275                     biere                      bieres
# 81169  preparation pour boisson  preparations pour boissons
# 8204                      grain                     graines
# 9985                      sauce                      sauces
# 83386                patisserie                 patisseries
# 73399                      lait                       laits
# 1640                 bruschetta                 bruschettas
# 76250                  biscotti                   biscottes
# 38732                    levain                     levains
# 76612                    farina                     farines

# %% [raw]
# Si main_category_fr_cor_2 n'est pas ''(vide) prendre main_category_fr_cor_2

# %%
categories.main_category_fr_cor_2[categories.main_category_fr_cor_2==""] = categories.main_category_fr_cor[categories.main_category_fr_cor_2==""]

# %% [markdown]
# </br>

# %%
categories.sample(10)
# Out:
#                                 main_category  \
# 41592  fr:garnitures-pour-bouchees-a-la-reine
# 63288                           de:gemusemais
# 69357                  en:biscuits-chocolates
# 84241                    en:fresh-raspberries
# 3731                        en:iced-green-tea
# 76317           it:yogurt-con-pezzi-di-frutta
# 9528                 en:instant-mashed-potato
# 65187                                  de:gin
# 25966                   fr:ananas-en-tranches
# 1174                              en:toppings
#
#                           main_category_fr  \
# 41592  Garnitures-pour-bouchees-a-la-reine
# 63288                        de:Gemusemais
# 69357               en:Biscuits-chocolates
# 84241                 en:Fresh-raspberries
# 3731                     en:Iced-green-tea
# 76317        it:Yogurt-con-pezzi-di-frutta
# 9528              en:Instant-mashed-potato
# 65187                               de:Gin
# 25966                   Ananas-en-tranches
# 1174                           en:Toppings
#
#                                     traduit  \
# 41592                                   NaN
# 63288                            Gemusemais
# 69357                    Biscuits chocolats
# 84241                   Framboises fraîches
# 3731                         Thé vert glacé
# 76317      Yoghourt avec morceaux de fruits
# 9528   Purée de pommes de terre instantanée
# 65187                                   Gin
# 25966                                   NaN
# 1174                               Nappages
#
#                        main_category_fr_cor  \
# 41592   garnitures pour bouchees a la reine
# 63288                            gemusemais
# 69357                    biscuits chocolats
# 84241                   framboises fraiches
# 3731                         the vert glace
# 76317      yoghourt avec morceaux de fruits
# 9528   puree de pommes de terre instantanee
# 65187                                   gin
# 25966                    ananas en tranches
# 1174                               nappages
#
#                      main_category_fr_cor_2
# 41592   garnitures pour bouchees a la reine
# 63288                            gemusemais
# 69357                    biscuits chocolats
# 84241                   framboises fraiches
# 3731                         the vert glace
# 76317      yoghourt avec morceaux de fruits
# 9528   puree de pommes de terre instantanee
# 65187                                   gin
# 25966                    ananas en tranches
# 1174                               nappages

# %% [raw]
# On a encore reduit le nombre de modalité.
# on passe de 3543 à 3033

# %%
categories.describe()
# Out:
#             main_category main_category_fr            traduit  \
# count                3543             3543               1860
# unique               3543             3543               1660
# top     fr:filet-de-boeuf   Filet-de-boeuf  Produits laitiers
# freq                    1                1                  9
#
#        main_category_fr_cor main_category_fr_cor_2
# count                  3543                   3543
# unique                 3164                   3033
# top       produits laitiers              chocolats
# freq                     10                     12

# %% [raw]
# Renommage de main_category_fr_cor_2

# %%
categories = categories.rename({'main_category_fr_cor_2': 'correction_main_category_fr'}, axis=1)

# %%
categories.head()
# Out:
#          main_category main_category_fr traduit main_category_fr_cor  \
# 0    fr:filet-de-boeuf   Filet-de-boeuf     NaN       filet de boeuf
# 1  en:fresh-vegetables    Légumes frais     NaN        legumes frais
# 2          en:pastries      Pâtisseries     NaN          patisseries
# 3            en:breads            Pains     NaN                pains
# 5          fr:boulange         Boulange     NaN             boulange
#
#   correction_main_category_fr
# 0              filet de boeuf
# 1               legumes frais
# 2                 patisseries
# 3                       pains
# 5                    boulange

# %% [raw]
# Export du resultat

# %%
categories.loc[categories.correction_main_category_fr!='',['main_category_fr','correction_main_category_fr']]\
.to_csv("correction_main_category_fr.csv",sep='\t')
